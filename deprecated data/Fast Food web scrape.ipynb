# %%
import pandas as pd

# %%
url = "https://www.qsrmagazine.com/content/qsr50-2017-top-50-chart"
tables = pd.read_html(url, header = 0)

# %%
df = tables[0]

# %%
df.head()
# Out:
#    QSR 50 Rank       Company Change in Position  Category  \
# 0            1   McDonald's*                  -    Burger
# 1            2   Starbucks*1                  -     Snack
# 2            3        Subway                  -  Sandwich
# 3            4       Wendy's                  2    Burger
# 4            5  Burger King*                 -1    Burger
#
#    2016 U.S. Systemwide Sales (millions)  \
# 0                               36389.00
# 1                               14795.40
# 2                               11300.00
# 3                                9510.00
# 4                                9749.19
#
#    2016 U.S. Average Sales Per Unit (thousands)  \
# 0                                       2550.00
# 1                                       1123.25
# 2                                        422.52
# 3                                       1454.80
# 4                                       1361.43
#
# ...

# %%
df.drop(df.columns[0], axis = 1, inplace = True)

# %%
df.drop(df.columns[1], axis = 1, inplace = True)

# %%
df.drop(df.columns[7], axis = 1, inplace = True)

# %%
df.head()
# Out:
#         Company  Category  2016 U.S. Systemwide Sales (millions)  \
# 0   McDonald's*    Burger                               36389.00
# 1   Starbucks*1     Snack                               14795.40
# 2        Subway  Sandwich                               11300.00
# 3       Wendy's    Burger                                9510.00
# 4  Burger King*    Burger                                9749.19
#
#    2016 U.S. Average Sales Per Unit (thousands)  \
# 0                                       2550.00
# 1                                       1123.25
# 2                                        422.52
# 3                                       1454.80
# 4                                       1361.43
#
#    Number of Franchised Units in 2016  Number of Company Units in 2016  \
# 0                               13046                             1109
# 1                                5292                             7880
# ...

# %%
df.to_csv("Fast_Food_Sales.csv", index = False)

# %%
url = "https://www.worldatlas.com/articles/us-states-by-population.html"
tables = pd.read_html(url, header = 0)

# %%
df = tables[0]

# %%
# df.set_index("Rank")

# %%
df.to_csv("state_populations.csv", index = False)

# %%
url = "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_coastline"
tables = pd.read_html(url, header = 0)
df = tables[0]
df.head()
# Out:
#   State or territory        Method 1 (CRS) Method 2 (NOAA)  \
# 0          Coastline                  Rank       Coastline
# 1             Alaska  6,640 mi (10,690 km)               1
# 2            Florida   1,350 mi (2,170 km)               2
# 3         California     840 mi (1,350 km)               3
# 4             Hawaii     750 mi (1,210 km)               4
#
#             Ratio(M2÷M1) Area[6] (mi2) Coast/area ratio (ft/mi2) Unnamed: 6  \
# 0                   Rank      Method 1                  Method 2        NaN
# 1  33,904 mi (54,563 km)             1                      5.11     665384
# 2   8,436 mi (13,576 km)             2                      6.25      65758
# 3    3,427 mi (5,515 km)             5                      4.08     163695
# 4    1,052 mi (1,693 km)            18                      1.40      10932
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN        NaN
# 1         53        NaN
# 2        110        680
# 3         27        110
# 4        360        510
